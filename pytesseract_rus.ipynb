# %% [markdown]
# # Tesseract5 OCR

# %%
# !pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.6-py2.py3-none-any.whl size=13629 sha256=5c2e63a7c9ca5cdfe887e68bac7132a6bbbc20ec72d15e7e5c0e0ffa3b580d4d
#   Stored in directory: /root/.cache/pip/wheels/ee/71/72/b98430261d849ae631e283dfc7ccb456a3fb2ed2205714b63f
# Successfully built pytesseract
# ...

# %%
import pytesseract
from PIL import Image

import os # it was nessesary for me

# %%
# os.chdir('D:\Education\Python\Project') # choose the current directory for this project

# %%
# pytesseract.pytesseract.tesseract_cmd = r'D:\Education\Python\Project\Tesseract5-OCR\tesseract.exe'

# %%
# Select the way to the tesseract.exe app
# This way is correct for the Google Collaboratory
pytesseract.pytesseract.tesseract_cmd = r'/usr/local/bin/pytesseract'

# %%
img_1 = Image.open('img1.jpg')
img_1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x720 at 0x1EB74A2D188>

# %%
img_2 = Image.open('img4.jpg')
img_2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=800x600 at 0x1EB74B1D408>

# %% [markdown]
# img_rus = [img_1,img_2]

# %%
for i in img_rus:
  print(i.filename)
# Out:
# img1.jpg
# img4.jpg

# %%
# the type of text is determed by configuration
custom_config = r'--oem 3 --psm 6'

# %%
for img in img_rus:
  file_name = img.filename
  file_name = file_name.split(".")[0]
  text = pytesseract.image_to_string(img, lang='rus', config=custom_config)
  with open(f'{file_name}.txt', 'w') as text_file:
    text_file.write(text)

# %%
# processing of the last photo
text.split('\n')
# Out:
# ['4 класс',
#  'второе полугодие',
#  'ВЕТЕР',
#  '',
#  'В давние времена ветер был человеком. Но затем',
#  'он превратился в птицу и стал летать. И стех пор',
#  'уже не мог ходить по земле, как было раньше.',
#  '',
#  'Поселился ветер-птица в пещере, в горах. Днем он',
#  'вылетал из пещеры и охотился весь день, а вечером',
#  'вновь возвращался в горы, в свою пещеру и проводил',
#  'там ночь.',
#  '',
#  'Случилось однажды, что человек увидал ветер.',
#  'Подумал он, что это птица, и бросил камень в птицу-',
#  'ветер. Рассердился ветер, разгневался, стал он',
#  'летать и дуть. Поднялась пыль, посыпались камни. Ни',
#  'один человек не мог ни охотиться, ни собирать',
#  'коренья. Все сидели в своих хижинах, ожидая. Когда',
#  'утихнет гнев ветра.',
#  '\x0c']
